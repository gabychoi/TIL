# %% [markdown]
# ### 학습 목표
# - 시각화 패키지 matplotlib
# - 서브 패키지 pyplot
# - seaborn
# - 분석된 내용을 시각화
# - Pandas 시각화 가능

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 한글 폰트 문제 해결
import platform

from matplotlib import font_manager, rc
# plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %% [markdown]
# - line plot : 데이터가 시간, 순서 등에 따라 어떻게 변화하는지 보여준다.

# %%
plt.title('line plot')
plt.plot([1,4,9,16])
plt.show()

# %%
plt.title('라인 플롯')
plt.plot([10,20,30,40],[1,4,9,16]) #앞이 x축, 뒤가 y축
plt.xlabel('x 라벨')
plt.ylabel('y 라벨')
plt.show()

# %% [markdown]
# - option(color , marker , style)
# - color : 약어 -> blue : b , red : r , green : g 라고 약어를 준다.
# - marker : o , s(square) 등
# - style : line style 의미 , - , -- , :
# - lw : 선 굵기
# - ls : 선 스타일
# - ms : 마커 크기
# - mec : 마커 선 색깔
# - mcw : 마커 선 굵기
# - mfc : 마커 내부 색깔

# %%
from IPython.display import Image
Image('C:/Users/i/images/line_style.png', width = 700)

# %%
plt.title('라인 플롯')
plt.plot([10,20,30,40] , [1,4,9,16] , 'bs--') #앞이 x축, 뒤가 y축, 선 스타일 지정
plt.xlabel('x 라벨')
plt.ylabel('y 라벨')
plt.show()

# %%
plt.title('스타일 적용 예')
plt.plot([10,20,30,40] , [1,4,9,16] , 
         c = 'b' , lw = 5 , ls = '--' , marker = 'o' , ms = 15 , mec = 'g' , mew = 5 , mfc = 'r') #앞이 x축, 뒤가 y축, 선 스타일 지정
plt.xlabel('x 라벨')
plt.ylabel('y 라벨')
plt.xlim()
plt.ylim()
plt.show()

# %% [markdown]
# - tick (xticks, yticks)

# %%
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False # 음수 부호 출력

X = np.linspace(-np.pi , np.pi , 256)
Y = np.cos(X)
plt.plot(X,Y)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, +1])
plt.show()

# %%
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False # 음수 부호 출력

X = np.linspace(-np.pi , np.pi , 256)
Y = np.cos(X)
plt.plot(X,Y)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, +1])
plt.grid(True) #격자무늬 생성
plt.show()

# %% [markdown]
# - 여러개의 라인 플롯을 그려보자.

# %%
data = np.arange(0.0, 5.0 , 0.2)
data
plt.title('여러개의 라인 플롯')
plt.plot(data , data, 'r--', data, data**2, 'b--', data, data**3, 'g--')
plt.show()

# %%
plt.title('라인을 겹쳐 그리기')
plt.plot([1,4,9,16] , 
         c = 'b' , lw = 5 , ls = '--' , marker = 'o' , ms = 15 , mec = 'g' , mew = 5 , mfc = 'r') 
plt.plot([9,16,4,1] , 
         c = 'k' , lw = 3 , ls = '--' , marker = 's' , ms = 10 , mec = 'm' , mew = 5 , mfc = 'c')
plt.show()

# %%
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False # 음수 부호 출력

X = np.linspace(-np.pi , np.pi , 256)
Y_C , Y_S = np.cos(X) , np.sin(X)
plt.plot(X , Y_C , ls='--' , label='cosine')
plt.plot(X , Y_S , ls='--' , label='sine')
plt.legend(loc=0) # loc로 범례의 위치 지정
plt.show()

# %% [markdown]
# - matplotlib 그림을 그리는 객체, Figure, Axes, Axis 객체를 포함하고 있다.
# - Figure -> 그림이 그려지는 종이를 뜻한다.
# - Axes -> 플롯
# - Axis -> 축

# %%
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False # 음수 부호 출력

np.random.seed(100)
plt.figure(figsize=(10,2)) # figure 사이즈 지정
plt.plot(np.random.randn(100))
plt.show()

# %% [markdown]
# - subplot(2,1,1)
# - subplot(2,1,2)

# %%
X1 = np.linspace(0.0, 5.0)
Y1 = np.cos(2 * np.pi * X1) * np.exp(-X1)
print(X1)
print(Y1)
X2 = np.linspace(0.0, 2.0)
Y2 = np.cos(2 * np.pi * X2)
print(X2)
print(Y2)
# Out:
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735 1.02040816 1.12244898
#  1.2244898  1.32653061 1.42857143 1.53061224 1.63265306 1.73469388
#  1.83673469 1.93877551 2.04081633 2.14285714 2.24489796 2.34693878
#  2.44897959 2.55102041 2.65306122 2.75510204 2.85714286 2.95918367
#  3.06122449 3.16326531 3.26530612 3.36734694 3.46938776 3.57142857
#  3.67346939 3.7755102  3.87755102 3.97959184 4.08163265 4.18367347
#  4.28571429 4.3877551  4.48979592 4.59183673 4.69387755 4.79591837
#  4.89795918 5.        ]
# [ 1.          0.72367065  0.2320026  -0.25429107 -0.55721991 -0.59913951
#  -0.41280458 -0.10893327  0.17893551  0.34780448  0.35748852  0.23380958
#   0.04690762 -0.12275601 -0.21591812 -0.21241248 -0.13137462 -0.01694367
#   0.08259904  0.1333648   0.12567347  0.0731473   0.00339549 -0.05472957
#  -0.08198104 -0.07402828 -0.04029719  0.00203856  0.03580865  0.05016511
# ...

# %%
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False # 음수 부호 출력

axes01 = plt.subplot(1,2,1) # 그래프를 그리는 캔버스 생성
plt.plot(X1, Y1)
plt.title('subplot 01')

axes02 = plt.subplot(1,2,2)
plt.plot(X2, Y2)
plt.title('subplot 02')

plt.tight_layout() # 자동으로 간격을 맞춰주는 기능
plt.show()

# %% [markdown]
# ### 플롯의 유형
# - line plot
# - scatter plot
# - contour plot
# - surface plot
# - bar plot
# - histogram plot
# - box plot

# %%
# bar plot
# x 데이터는 카테고리 값인 경우가 대부분이다.

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pylab as plt
# %matplotlib inline

Y = [2, 3, 1]
X = np.arange(len(Y))
X

xlabel = ['1등실', '2등실', '3등실']
plt.title('bar plot')
plt.bar(X, Y) 
plt.xticks(X, xlabel)
plt.yticks(sorted(Y))
plt.xlabel('선실 등급')
plt.ylabel('생존자 수')
plt.show()

# %%
# barh plot : horizental 형식으로 그래프를 그려준다.

Y = [2, 3, 1]
X = np.arange(len(Y))
X

xlabel = ['1등실', '2등실', '3등실']
plt.title('bar plot')
plt.barh(X, Y) 
plt.xticks(X, xlabel)
plt.yticks(sorted(Y))
plt.xlabel('선실 등급')
plt.ylabel('생존자 수')
plt.show()

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
iris['species'].value_counts()
# Out:
# virginica     50
# setosa        50
# versicolor    50
# Name: species, dtype: int64

# %%
iris.rename(columns={iris.columns[0] : 'SL', iris.columns[1] : 'SW', iris.columns[2] : 'PL', iris.columns[3] : 'PW', iris.columns[4] : 'Y'}, inplace=True)

# %%
iris.head()
# Out:
#     SL   SW   PL   PW       Y
# 0  5.1  3.5  1.4  0.2  setosa
# 1  4.9  3.0  1.4  0.2  setosa
# 2  4.7  3.2  1.3  0.2  setosa
# 3  4.6  3.1  1.5  0.2  setosa
# 4  5.0  3.6  1.4  0.2  setosa

# %%
iris[['SL' , 'SW']][ : 5]
# Out:
#     SL   SW
# 0  5.1  3.5
# 1  4.9  3.0
# 2  4.7  3.2
# 3  4.6  3.1
# 4  5.0  3.6

# %%
# EDA
# 종을 기준으로 그룹화하여 각 그룹의 평균을 구해보자
species_mean = iris.groupby('Y').mean()
species_mean
# Out:
#                SL     SW     PL     PW
# Y
# setosa      5.006  3.428  1.462  0.246
# versicolor  5.936  2.770  4.260  1.326
# virginica   6.588  2.974  5.552  2.026

# %%
species_mean.columns.name = 'SP' #컬럼 이름 생성
species_mean
# Out:
# SP             SL     SW     PL     PW
# Y
# setosa      5.006  3.428  1.462  0.246
# versicolor  5.936  2.770  4.260  1.326
# virginica   6.588  2.974  5.552  2.026

# %%
species_mean.T #전치행렬 변환, 행과 열 바꾸기
# Out:
# Y   setosa  versicolor  virginica
# SP
# SL   5.006       5.936      6.588
# SW   3.428       2.770      2.974
# PL   1.462       4.260      5.552
# PW   0.246       1.326      2.026

# %%
species_mean.T.plot.bar(rot=0)
plt.title('각 변수별 평균')
plt.xlabel('평균')
plt.ylabel('변수')
plt.ylim(0,8)
plt.show()

# %%
species_mean.plot.bar()

# %% [markdown]
# - iris boxplot 을 그려보자

# %%
iris[['SL' , 'Y']].head()
# Out:
#     SL       Y
# 0  5.1  setosa
# 1  4.9  setosa
# 2  4.7  setosa
# 3  4.6  setosa
# 4  5.0  setosa

# %%
iris[['SL' , 'Y']].boxplot(by='Y')
plt.title('종에 따른 SL boxplot')
plt.xlabel('type')
plt.ylabel('cm')
plt.tight_layout(pad=3)
plt.show()

# %%
iris[['SW' , 'Y']].boxplot(by='Y')
plt.title('종에 따른 SW boxplot')
plt.xlabel('type')
plt.ylabel('cm')
plt.tight_layout(pad=3)
plt.show()

# %%
iris[['PW' , 'Y']].boxplot(by='Y')
plt.title('종에 따른 PW boxplot')
plt.xlabel('type')
plt.ylabel('cm')
plt.tight_layout(pad=3)
plt.show()

# %%
iris[['PL' , 'Y']].boxplot(by='Y')
plt.title('종에 따른 PL boxplot')
plt.xlabel('type')
plt.ylabel('cm')
plt.tight_layout(pad=3)
plt.show()

# %%
# subplot 으로 그래프 그리기 : 하나의 캔버스에 여러 개의 그래프 생성하는 subplot

fig , axes = plt.subplots(nrows=2 , ncols=2, figsize=(20,10))
ax = axes.flatten()

iris[['SL' , 'Y']].boxplot(by='Y' , ax=ax[0])
plt.title('종에 따른 SL boxplot')
plt.xlabel('type')
plt.ylabel('cm')

iris[['SW' , 'Y']].boxplot(by='Y' , ax=ax[1])
plt.title('종에 따른 SL boxplot')
plt.xlabel('type')
plt.ylabel('cm')

iris[['PL' , 'Y']].boxplot(by='Y' , ax=ax[2])
plt.title('종에 따른 SL boxplot')
plt.xlabel('type')
plt.ylabel('cm')

iris[['PW' , 'Y']].boxplot(by='Y', ax=ax[3])
plt.title('종에 따른 SL boxplot')
plt.xlabel('type')
plt.ylabel('cm')
# Out:
# Text(0,0.5,'cm')

# %% [markdown]
# ### car_mpg.xls [실습]

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
xls = pd.ExcelFile('C:/Users/i/data/car_mpg.xlsx')

# %%
data_df = xls.parse(xls.sheet_names[0])
data_df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
# manufacturer    234 non-null object
# model           234 non-null object
# displ           234 non-null float64
# year            234 non-null int64
# cyl             234 non-null int64
# trans           234 non-null object
# drv             234 non-null object
# cty             234 non-null int64
# hwy             234 non-null int64
# fl              234 non-null object
# class           234 non-null object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
data_df['fl'].head()
# Out:
# 1    p
# 2    p
# 3    p
# 4    p
# 5    p
# Name: fl, dtype: object

# %%
row , col = data_df.shape
print('row : ', row)
print('col : ', col)
# Out:
# row :  234
# col :  11

# %%
data_df.describe() #통계값 출력
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# - 양적 자료 : 요약 정보에 집계가 되는 컬럼으로 관측된 값이 수치 형태의 속성을 가지는 자료
# - 양적 자료의 시각화 : boxplot
# - ex) 배기량 , 생산년도 , 실린더 개수 , 도시 연비, 고속도로 연비 (mpg data의 변수)
#
# - 질적 자료 : 범주형 또는 순서형의 속성을 가지는 자료로서 도수 분포표와 히스토그램으로 데이터의 분포를 확인해야 하는 값들
# - ex) 제조회사 , 모델명 , 변속기 종류 , 구동 방식 , 연료 종류 , 자동차 종류

# %%
# 양적 자료의 데이터 분포 확인(boxplot)

data_df.boxplot(['displ' , 'cyl' , 'cty' , 'hwy'])
plt.show()

# %%
# 질적 자료에 대한 데이터 빈도 확인
# 제조회사, 모델명, 변속기 종류, 구동방식, 연료종류, 자동차 종류

data_df['class'].value_counts()
# Out:
# suv           62
# compact       47
# midsize       41
# subcompact    35
# pickup        33
# minivan       11
# 2seater        5
# Name: class, dtype: int64

# %%
data_df['displ'].value_counts()

# 자동차 배기량에 따라 고속도로 연비가 다른지를 알아보자
# 배기량이 4 이하인 자동차와 5 이상인 자동차 중 어떤 자동차의 고속도로 연비가 평균적으로 높은지 알아보자

displ01 = data_df[data_df['displ']<= 4]
displ02 = data_df[data_df['displ']>= 5]

displ_less4_mean = displ01['hwy'].mean()
displ_more5_mean = displ02['hwy'].mean()

display(displ_less4_mean)
display(displ_more5_mean)

# or

data_df.query('displ <= 4')['hwy'].mean()
data_df.query('displ >= 5')['hwy'].mean()
# Out:
# 25.96319018404908
# 18.07894736842105
# 18.07894736842105

# %% [markdown]
# - query() 함수 : 조건식을 넣어 원하는 조건에 맞는 행을 추출할 때 사용

# %%
query_df = pd.DataFrame(np.random.randint(0, 10, size=(10, 3)), columns=['col01', 'col02', 'col03'])
query_df
# Out:
#    col01  col02  col03
# 0      1      5      9
# 1      2      5      6
# 2      4      6      7
# 3      9      7      3
# 4      0      2      5
# 5      1      1      0
# 6      3      6      7
# 7      3      6      4
# 8      8      6      5
# 9      0      0      5

# %%
query_df.query('col01 > 2 and col02 < 5')
# Out:
# Empty DataFrame
# Columns: [col01, col02, col03]
# Index: []

# %%
# 문제 02
# 자동차 제조 회사에 따라 도시 연비가 다른지 알아보려고 한다.
# audi와 toyota 중 어느 manufacturer (자동차 제조 회사)의 cty(도시연비)가 평균적으로 더 높은지 알아보라.

print(data_df.query('manufacturer == "audi"')['cty'].mean())
print(data_df.query('manufacturer == "toyota"')['cty'].mean())
# Out:
# 17.61111111111111
# 18.529411764705884

# %%
# 문제 03
# chevrolet , ford , honda 자동차의 고속도로 연비 평균을 알아보라.
# 이 회사 데이터를 추출한 후 hwy 전체 평균을 확인하라.
manufac_car = ['chevrolet', 'ford', 'honda']
print(data_df.query('manufacturer in @manufac_car')['hwy'].mean())

print (data_df.query('manufacturer == "chevrolet" or \
                      manufacturer == "ford" or \
                      manufacturer == "honda"') ['hwy'].mean())
                
print(data_df[(data_df['manufacturer']=='chervrolet') |
              (data_df['manufacturer']=='ford') |
              (data_df['manufacturer']=='honda')]['hwy'].mean())
# Out:
# 22.50943396226415
# 22.50943396226415
# 22.852941176470587

# %%
chevrolet_index   = data_df['manufacturer'] == 'chevrolet'
ford_index        = data_df['manufacturer'] == 'ford'
honda_index       = data_df['manufacturer'] == 'honda'

temp_df = data_df.loc[chevrolet_index | ford_index | honda_index, :]
mean_df = temp_df[ ['manufacturer', 'hwy'] ].groupby(temp_df.manufacturer).agg(np.mean)
mean_df.plot.bar()

display(mean_df)
print('세 자동차 회사의 hwy의 평균 : ', temp_df['hwy'].mean())
# Out:
#                     hwy
# manufacturer
# chevrolet     21.894737
# ford          19.360000
# honda         32.555556
# 세 자동차 회사의 hwy의 평균 :  22.50943396226415

# %%
data_df[(data_df['manufacturer']=='chervrolet') |
              (data_df['manufacturer']=='ford') |
              (data_df['manufacturer']=='honda')]['hwy']
# Out:
# 75     17
# 76     17
# 77     18
# 78     17
# 79     19
# 80     17
# 81     19
# 82     19
# 83     17
# 84     17
# 85     17
# 86     16
# 87     16
# 88     17
# 89     15
# 90     17
# 91     26
# 92     25
# 93     26
# 94     24
# 95     21
# 96     22
# 97     23
# 98     22
# 99     20
# 100    33
# 101    32
# 102    32
# 103    29
# 104    32
# 105    34
# 106    36
# 107    36
# 108    29
# Name: hwy, dtype: int64

# %%
data_df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %% [markdown]
# - 데이터 전처리 : 연료 가격 변수 추가
# - c : 가스 2.35, d : 디젤 2.38, e : 에탄올 2.11, p : 고급휘발유 2.76, r:보통휘발유 2.22

# %%
fl_df = pd.DataFrame({
    "fl" : ['c', 'd', 'e', 'p', 'r'],
    "price_fl" : [2.35, 2.38, 2.11, 2.76, 2.22]
})
fl_df
# Out:
#   fl  price_fl
# 0  c      2.35
# 1  d      2.38
# 2  e      2.11
# 3  p      2.76
# 4  r      2.22

# %%
# 우리가 만든 연료 가격 프레임을 원본 프레임에 병합

data_fl_merge_df = pd.merge(data_df, fl_df, on='fl', how='inner')
data_fl_merge_df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    price_fl
# 0      2.76
# 1      2.76
# 2      2.76
# 3      2.76
# 4      2.76

# %%
# merge 한 데이터 프레임에서 model, fl, price_fl 만 추출
data_fl_merge_df[['model', 'fl', 'price_fl']].head()
# Out:
#   model fl  price_fl
# 0    a4  p      2.76
# 1    a4  p      2.76
# 2    a4  p      2.76
# 3    a4  p      2.76
# 4    a4  p      2.76

# %%
# 데이터 전처리 과정에서 결측값 확인하기
data_fl_merge_df.isna().sum()
# Out:
# manufacturer    0
# model           0
# displ           0
# year            0
# cyl             0
# trans           0
# drv             0
# cty             0
# hwy             0
# fl              0
# class           0
# price_fl        0
# dtype: int64

# %%
# 구동방식(drv) 별 고속도로 연비(hwy) 평균
# 임의적으로 결측값 처리 위해 더미값 넣어보도록 하자
data_fl_merge_df.loc[65, 'hwy'] = np.nan
data_fl_merge_df.loc[120, 'hwy'] = np.nan
data_fl_merge_df.loc[154, 'hwy'] = np.nan
data_fl_merge_df.loc[189, 'hwy'] = np.nan
data_fl_merge_df.loc[219, 'hwy'] = np.nan
data_fl_merge_df.loc[230, 'hwy'] = np.nan

# %%
# 데이터 전처리 과정에서 결측값 확인하기
data_fl_merge_df[['drv', 'hwy']].isna().sum()
data_fl_merge_df.filter(['drv', 'hwy']).isna().sum()
# Out:
# drv    0
# hwy    6
# dtype: int64

# %%
data_fl_merge_df['drv'].value_counts()
# Out:
# f    106
# 4    103
# r     25
# Name: drv, dtype: int64

# %%
# hwy 변수의 결측값을 제외하고, 어떤 구동방식의 고속도로 평균 연비가 높은지 알아보자

data_fl_merge_isna_df = data_fl_merge_df.filter(['drv', 'hwy']).dropna()
print(data_fl_merge_isna_df.info())

drv_group_df = data_fl_merge_isna_df.groupby('drv').mean()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 228 entries, 0 to 233
# Data columns (total 2 columns):
# drv    228 non-null object
# hwy    228 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 5.3+ KB
# None

# %%
# 구동방식별 도시 연비 평균을 비교하기 위한 막대 그래프로 시각화해보자.
drv_group_df.plot.bar(rot=0)
plt.title('구동방식별 평균연비')
plt.xlabel('구동방식')
plt.ylabel('연비')
plt.grid()
plt.show()

# %% [markdown]
# ### 실습

# %%
# 위에서 했던 방식과 동일하게 구동방식별 고속도로, 도시연비의 평균을 구하고
# 이를 데이터 프레임으로 만들어 막대바로 시각화해보자.

data_drv_h_c = data_fl_merge_df.filter(['drv', 'hwy', 'cty']).dropna()
print(data_drv_h_c.info())

drv_group_df = data_drv_h_c.groupby('drv').mean()

drv_group_df.plot.bar(rot=0)
plt.title('구동방식별 평균연비')
plt.xlabel('구동방식')
plt.ylabel('연비')
plt.grid()
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 228 entries, 0 to 233
# Data columns (total 3 columns):
# drv    228 non-null object
# hwy    228 non-null float64
# cty    228 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 7.1+ KB
# None

# %%
# 자동차(class) 중에서 어떤 자동차가 가장 많은지 알아보려고 한다.
# 종류별 빈도를 막대바로 시각화해보자.

data_class = pd.DataFrame(data_fl_merge_df['class'].value_counts())
data_class

data_class.plot.bar(rot=0)
plt.title('자동차 크기별 개수')
plt.xlabel('자동차 크기')
plt.grid()
plt.show()

# %%
# 어떤 회사에서 생산한 suv 차종의 도시 연비가 높은지 알아보려고 한다.
# suv 차종을 대상으로 평균 도시연비가 가장 높은 회사 5곳을 막대바로 시각화해보자.

suv_data = data_fl_merge_df[data_fl_merge_df['class'] == 'suv']
suv_data
cty_data = suv_data[['manufacturer', 'cty']]
manu_group = cty_data.groupby('manufacturer')
top5_manufac = manu_group.mean().sort_values(by='cty', ascending=False)[0:5]

top5_manufac.plot.bar(rot=0)
plt.title('제조사별 도시 연비 TOP5')
plt.xlabel('제조사')
plt.ylabel('도시 연비')
plt.grid()
plt.show()

# %%
### 이상치 정제

# car_mpg 데이터에서 구동방식별 고속도로 연비 평균과 도시 연비 평균을 극단치를 제외하고 확인
# 각 연비별 이상치 확인 boxplot()

outlier_df = data_df.filter(['hwy', 'cty'])
outlier_df.boxplot()
plt.show()

# %%
# 3사분위 정보를 얻어보자
quantile75 = outlier_df.quantile(q=0.75)
quantile75
# Out:
# hwy    27.0
# cty    19.0
# Name: 0.75, dtype: float64

# %%
# 1사분위 정보를 얻어보자
quantile25 = outlier_df.quantile(q=0.25)
quantile25
# Out:
# hwy    18.0
# cty    14.0
# Name: 0.25, dtype: float64

# %%
# IQR (3사분위 수 - 1사분위 수)
iqr = quantile75 - quantile25
iqr
# Out:
# hwy    9.0
# cty    5.0
# dtype: float64

# %%
# 최저 한계치(lower fence)
lower_fence = quantile25 - 1.5 * iqr
print('lower_fence\n' , lower_fence) # \n은 개행, 아랫줄로 내린다.

# 최고 한계치(upper fence)
upper_fence = quantile75 + 1.5 * iqr
print('upper_fence\n' , upper_fence)
# Out:
# lower_fence
#  hwy    4.5
# cty    6.5
# dtype: float64
# upper_fence
#  hwy    40.5
# cty    26.5
# dtype: float64

# %%
# outlier_df 
# 극단치 경계 값을 얻어보자 (아래 수평선)
lower_outlier = outlier_df[outlier_df > lower_fence].min()
lower_outlier
# Out:
# hwy    12
# cty     9
# dtype: int64

# %%
# 극단치 경계 값을 얻어보자 (위 수평선)
upper_outlier = outlier_df[ outlier_df < upper_fence ].max()
upper_outlier
# Out:
# hwy    37.0
# cty    26.0
# dtype: float64

# %%
# 이상치를 결측값으로 변경
# 고속도로 연비의 이상치 데이터 추출
hwy_outlier_df = data_df.query('hwy > '+str(upper_outlier['hwy']))
hwy_outlier_df
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 213   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 222   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 223   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#           class
# 213     compact
# 222  subcompact
# 223  subcompact

# %%
# 도시 연비의 이상치 데이터 추출
cty_outlier_df = data_df.query('cty > '+str(upper_outlier['cty']))
cty_outlier_df
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 100        honda       civic    1.6  1999    4  manual(m5)   f   28   33  r
# 197       toyota     corolla    1.8  2008    4  manual(m5)   f   28   37  r
# 213   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 222   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 223   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#           class
# 100  subcompact
# 197     compact
# 213     compact
# 222  subcompact
# 223  subcompact

# %%
# copy()
outlier_clean_df = data_df.copy()
outlier_clean_df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
# hwy 연비에 대한 이상치를 결측값으로 변경
for idx in hwy_outlier_df.index :
    #print(idx)
    outlier_clean_df.loc[idx, 'hwy'] = np.nan
outlier_clean_df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty   hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18  29.0  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21  29.0  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20  31.0  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21  30.0  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16  26.0  p  compact

# %%
# cty 연비에 대한 이상치를 결측값으로 변경
for idx in cty_outlier_df.index :
    #print(idx)
    outlier_clean_df.loc[idx, 'cty'] = np.nan
outlier_clean_df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv   cty   hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f  18.0  29.0  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f  21.0  29.0  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f  20.0  31.0  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f  21.0  30.0  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f  16.0  26.0  p  compact

# %%
# 결측값 있는지 확인
outlier_clean_df.filter(['cty', 'hwy']).isna().sum()
# Out:
# cty    5
# hwy    3
# dtype: int64

# %%
# 결측값 제거한 구동방식별 고속도로, 도시 연비 평균
drv_mean_df = outlier_clean_df.filter(['drv', 'hwy', 'cty']).dropna().groupby('drv').mean()
drv_mean_df
# Out:
#            hwy        cty
# drv
# 4    19.174757  14.330097
# f    27.584158  19.445545
# r    21.000000  14.080000

# %%
# 시각화
drv_mean_df.plot.bar(rot=0)
plt.grid()
plt.title('이상치 제거한 고속도로, 도시 평균 연비 비교')
plt.xlabel('구동방식')
plt.ylabel('평균연비')
plt.show()

# %%
drv_mean_df = outlier_clean_df.filter(['hwy', 'cty'])
drv_mean_df.boxplot()
plt.show()
