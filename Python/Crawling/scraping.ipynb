# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.error   import HTTPError
from urllib.error   import URLError

# %%
base_url = 'https://movie.naver.com/'
sub_url  = 'movie/sdb/rank/rmovie.nhn?sel=cur&date=20170501'

try:
    html = urlopen(base_url+sub_url)
except HTTPError as he :
    print('http error')
except URLError as ue :
    print('url error')
else :
    soup = BeautifulSoup(html.read() , 'html.parser')

# %%
soup.find_all('div', 'tit5')[0].a.get_text()
# Out:
# '히든 피겨스'

# %%
soup.find_all('div', 'tit5')[1]
# Out:
# <div class="tit5">
# <a href="/movie/bi/mi/basic.nhn?code=10102" title="사운드 오브 뮤직">사운드 오브 뮤직</a>
# </div>

# %% [markdown]
# - 평점을 추출한다면

# %%
soup.find_all('td', 'point')[0].string
# Out:
# '9.38'

# %% [markdown]
# - dataframe 을 만들기 위해서는 셀의 길이가 동일해야 하므로 확인 절차가 필요하다.

# %%
print('영화이름 : ', len(soup.find_all('div', 'tit5')))
print('평점 : ', len(soup.find_all('td', 'point')))
# Out:
# 영화이름 :  50
# 평점 :  50

# %%
move_names = [soup.find_all('div', 'tit5')[n].a.get_text() for n in range(0,50)]
print(len(move_names))
print(move_names)
# Out:
# 50
# ['히든 피겨스', '사운드 오브 뮤직', '시네마 천국', '미스 슬로운', '잉여들의 히치하이킹', '나, 다니엘 블레이크', '바람과 함께 사라지다', '오즈의 마법사', '벤허', '흑집사 : 북 오브 더 아틀란틱', '우리들', '일 포스티노', '댄서', '라이언', '코알라', '로건', '더 플랜', '분노의 질주: 더 익스트림', '시카고', '10분', '해리가 샐리를 만났을 때', '미녀와 야수', '너의 이름은.', '그랑블루', '한공주', '연애담', '포켓몬 더 무비 XY&Z; 「볼케니온 : 기계왕국의 비밀」', '리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국', '분노', '맨체스터 바이 더 씨', '행복 목욕탕', '스머프: 비밀의 숲', '부당거래', '파닥파닥', '아비정전', '패션 오브 크라이스트', '라라랜드', '뽀로로 극장판 슈퍼썰매 대모험', '족구왕', '가디언즈 오브 갤럭시', '자전거 탄 소년', '오두막', '성실한 나라의 앨리스', '원라인', '존 윅 - 리로드', '사일런스', '클로저', '임금님의 사건수첩', '문라이트', '로미오와 줄리엣']

# %%
move_points = [soup.find_all('td', 'point')[n].get_text() for n in range(0,50)]
print(len(move_points))
print(move_points)
# Out:
# 50
# ['9.38', '9.36', '9.29', '9.26', '9.25', '9.25', '9.24', '9.23', '9.22', '9.20', '9.18', '9.17', '9.14', '9.07', '9.07', '9.06', '9.04', '9.02', '8.92', '8.89', '8.89', '8.85', '8.81', '8.78', '8.78', '8.76', '8.75', '8.73', '8.73', '8.72', '8.70', '8.67', '8.66', '8.65', '8.59', '8.59', '8.59', '8.56', '8.56', '8.56', '8.54', '8.48', '8.39', '8.29', '8.28', '8.26', '8.20', '8.17', '8.12', '8.10']

# %%
import pandas as pd

# %%
date = pd.date_range('2017-5-1', periods=100 , freq='D')
date
# Out:
# DatetimeIndex(['2017-05-01', '2017-05-02', '2017-05-03', '2017-05-04',
#                '2017-05-05', '2017-05-06', '2017-05-07', '2017-05-08',
#                '2017-05-09', '2017-05-10', '2017-05-11', '2017-05-12',
#                '2017-05-13', '2017-05-14', '2017-05-15', '2017-05-16',
#                '2017-05-17', '2017-05-18', '2017-05-19', '2017-05-20',
#                '2017-05-21', '2017-05-22', '2017-05-23', '2017-05-24',
#                '2017-05-25', '2017-05-26', '2017-05-27', '2017-05-28',
#                '2017-05-29', '2017-05-30', '2017-05-31', '2017-06-01',
#                '2017-06-02', '2017-06-03', '2017-06-04', '2017-06-05',
#                '2017-06-06', '2017-06-07', '2017-06-08', '2017-06-09',
#                '2017-06-10', '2017-06-11', '2017-06-12', '2017-06-13',
#                '2017-06-14', '2017-06-15', '2017-06-16', '2017-06-17',
#                '2017-06-18', '2017-06-19', '2017-06-20', '2017-06-21',
#                '2017-06-22', '2017-06-23', '2017-06-24', '2017-06-25',
#                '2017-06-26', '2017-06-27', '2017-06-28', '2017-06-29',
#                '2017-06-30', '2017-07-01', '2017-07-02', '2017-07-03',
#                '2017-07-04', '2017-07-05', '2017-07-06', '2017-07-07',
#                '2017-07-08', '2017-07-09', '2017-07-10', '2017-07-11',
#                '2017-07-12', '2017-07-13', '2017-07-14', '2017-07-15',
#                '2017-07-16', '2017-07-17', '2017-07-18', '2017-07-19',
#                '2017-07-20', '2017-07-21', '2017-07-22', '2017-07-23',
#                '2017-07-24', '2017-07-25', '2017-07-26', '2017-07-27',
#                '2017-07-28', '2017-07-29', '2017-07-30', '2017-07-31',
#                '2017-08-01', '2017-08-02', '2017-08-03', '2017-08-04',
#                '2017-08-05', '2017-08-06', '2017-08-07', '2017-08-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
import urllib
from tqdm import tqdm_notebook
import time

# %%
for n in tqdm_notebook(range(2), desc='outer') :
    for y in tqdm_notebook(range(1000) , desc='inner') :
        time.sleep(0.1)
# 진행상태바 볼 때 사용하면 좋다
# Out:
# C:\Users\i\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """Entry point for launching an IPython kernel.
# HBox(children=(FloatProgress(value=0.0, description='outer', max=2.0, style=ProgressStyle(description_width='i…
# C:\Users\i\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, description='inner', max=1000.0, style=ProgressStyle(description_width…
# HBox(children=(FloatProgress(value=0.0, description='inner', max=1000.0, style=ProgressStyle(description_width…

# %%
names_result = []
points_result = []
date_result = []

# %%
base_url = 'https://movie.naver.com/'
sub_url  = 'movie/sdb/rank/rmovie.nhn?sel=cur&date='
for day in tqdm_notebook(date):
    html = base_url+sub_url+'{date}'
    response = urlopen(html.format(date=urllib.parse.quote(day.strftime('%Y%m%d'))))
    soup = BeautifulSoup(response, 'html.parser')
    end = len(soup.find_all('td', 'point'))
    names_result.extend([ soup.find_all('div', 'tit5')[n].a.string for n in range(0,end)])
    points_result.extend([ soup.find_all('td', 'point')[n].string for n in range(0,end)])
    date_result.extend([day for n in range(0,end)])
# Out:
# C:\Users\i\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))

# %%
print(len(names_result))
print(len(points_result))
print(len(date_result))
# Out:
# 4723
# 4723
# 4723

# %%
movieDF = pd.DataFrame({'date' : date_result , 'name' : names_result , 'point' : points_result})

# %%
movieDF
# Out:
#            date                              name point
# 0    2017-05-01                            히든 피겨스  9.38
# 1    2017-05-01                         사운드 오브 뮤직  9.36
# 2    2017-05-01                            시네마 천국  9.29
# 3    2017-05-01                            미스 슬로운  9.26
# 4    2017-05-01                        잉여들의 히치하이킹  9.25
# 5    2017-05-01                       나, 다니엘 블레이크  9.25
# 6    2017-05-01                       바람과 함께 사라지다  9.24
# 7    2017-05-01                           오즈의 마법사  9.23
# 8    2017-05-01                                벤허  9.22
# 9    2017-05-01                 흑집사 : 북 오브 더 아틀란틱  9.20
# 10   2017-05-01                               우리들  9.18
# 11   2017-05-01                            일 포스티노  9.17
# 12   2017-05-01                                댄서  9.14
# 13   2017-05-01                               라이언  9.07
# 14   2017-05-01                               코알라  9.07
# 15   2017-05-01                                로건  9.06
# 16   2017-05-01                              더 플랜  9.04
# 17   2017-05-01                    분노의 질주: 더 익스트림  9.02
# 18   2017-05-01                               시카고  8.92
# 19   2017-05-01                               10분  8.89
# 20   2017-05-01                     해리가 샐리를 만났을 때  8.89
# 21   2017-05-01                            미녀와 야수  8.85
# 22   2017-05-01                           너의 이름은.  8.81
# 23   2017-05-01                              그랑블루  8.78
# 24   2017-05-01                               한공주  8.78
# 25   2017-05-01                               연애담  8.76
# 26   2017-05-01  포켓몬 더 무비 XY&Z; 「볼케니온 : 기계왕국의 비밀」  8.75
# 27   2017-05-01      리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국  8.73
# 28   2017-05-01                                분노  8.73
# 29   2017-05-01                       맨체스터 바이 더 씨  8.72
# ...         ...                               ...   ...
# 4693 2017-08-08                            노무현입니다  8.93
# 4694 2017-08-08                            파이트 클럽  8.91
# 4695 2017-08-08                          스타쉽 트루퍼스  8.90
# 4696 2017-08-08                                청원  8.87
# 4697 2017-08-08                             토탈 리콜  8.86
# 4698 2017-08-08        극장판 짱구는 못말려 : 습격!! 외계인 덩덩이  8.78
# 4699 2017-08-08                           너의 이름은.  8.76
# 4700 2017-08-08                               연애담  8.75
# 4701 2017-08-08                            슈퍼배드 3  8.72
# 4702 2017-08-08                             꿈의 제인  8.71
# 4703 2017-08-08                             심야식당2  8.62
# 4704 2017-08-08                              라라랜드  8.59
# 4705 2017-08-08                        카3: 새로운 도전  8.59
# 4706 2017-08-08                               오두막  8.49
# 4707 2017-08-08                        스파이더맨: 홈커밍  8.48
# 4708 2017-08-08                                옥자  8.47
# 4709 2017-08-08                          500일의 썸머  8.39
# 4710 2017-08-08                          복수는 나의 것  8.34
# 4711 2017-08-08                              덩케르크  8.33
# 4712 2017-08-08                           예수는 역사다  8.10
# 4713 2017-08-08                            매치 포인트  7.97
# 4714 2017-08-08                       7번째 내가 죽던 날  7.85
# 4715 2017-08-08                             위시 어폰  7.69
# 4716 2017-08-08                             47 미터  7.38
# 4717 2017-08-08                           친절한 금자씨  7.26
# 4718 2017-08-08                             송 투 송  6.88
# 4719 2017-08-08                               그 후  6.58
# 4720 2017-08-08                                박쥐  6.09
# 4721 2017-08-08                        싸이보그지만 괜찮아  5.17
# 4722 2017-08-08                               군함도  5.02
#
# [4723 rows x 3 columns]

# %%
movieDF.tail()
# Out:
#            date        name point
# 4718 2017-08-08       송 투 송  6.88
# 4719 2017-08-08         그 후  6.58
# 4720 2017-08-08          박쥐  6.09
# 4721 2017-08-08  싸이보그지만 괜찮아  5.17
# 4722 2017-08-08         군함도  5.02

# %%
movieDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4723 entries, 0 to 4722
# Data columns (total 3 columns):
# date     4723 non-null datetime64[ns]
# name     4723 non-null object
# point    4723 non-null object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 110.8+ KB

# %% [markdown]
# - astype() 함수를 이용해서 컬럼의 타입을 변경할 수 있다.

# %%
type(movieDF['point'])
# 벡터라는 시리즈형식??
# Out:
# pandas.core.series.Series

# %%
movieDF['point'] = movieDF['point'].astype(float)

# %%
movieDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4723 entries, 0 to 4722
# Data columns (total 3 columns):
# date     4723 non-null datetime64[ns]
# name     4723 non-null object
# point    4723 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 110.8+ KB

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# - 내가 원하는 영화의 평점을 총점으로 확인하고 싶다면??
# - 피봇 테이블을 이용할 수 있습니다.

# %%
movie_pivot = pd.pivot_table(movieDF , index=['name'] , aggfunc=np.sum)
movie_pivot
# Out:
#                                    point
# name
# 10분                               124.46
# 47 미터                             149.23
# 500일의 썸머                           75.51
# 7년-그들이 없는 언론                      137.28
# 7번째 내가 죽던 날                       407.48
# 7인의 사무라이                           36.60
# 8 마일                              195.36
# 가디언즈 오브 갤럭시                        34.22
# 가디언즈 오브 갤럭시 VOL. 2                484.45
# 겟 아웃                              630.62
# 공각기동대 : 고스트 인 더 쉘                  49.89
# 군함도                                54.49
# 그 후                                52.95
# 그녀                                238.00
# 그랑블루                              193.13
# 그물                                 86.62
# 극장판 짱구는 못말려 : 습격!! 외계인 덩덩이        106.14
# 극장판 쿠로코의 농구 라스트 게임                370.45
# 기쿠지로의 여름                          613.43
# 꿈의 제인                             428.90
# 나, 다니엘 블레이크                       434.64
# 나는 부정한다                           231.90
# 나의 붉은 고래                          140.02
# 나의 사랑, 그리스                        169.03
# 내 사랑                              220.31
# 너와 100번째 사랑                       330.27
# 너의 이름은.                           738.42
# 노무현입니다                            682.24
# 눈길                                411.89
# 눈발                                 75.82
# ...                                  ...
# 택시운전사                              63.05
# 토탈 리콜                             132.90
# 트랜스포머: 최후의 기사                     238.59
# 트랜스포머: 패자의 역습                      48.66
# 특별시민                              280.85
# 티파니에서 아침을                          33.56
# 파닥파닥                              147.05
# 파도가 지나간 자리                        315.27
# 파워레인져스: 더 비기닝                     170.81
# 파이트 클럽                             80.19
# 패션 오브 크라이스트                        34.38
# 페인티드 베일                            17.12
# 포켓몬 더 무비 XY&Z; 「볼케니온 : 기계왕국의 비밀」   69.96
# 프랭크                               270.64
# 프리즌                                61.40
# 플래툰                               329.23
# 플립                                229.81
# 피아니스트                             116.18
# 피와 뼈                              197.09
# 하루                                291.82
# 하울의 움직이는 성                         91.00
# 하이큐!! 끝과 시작                       312.08
# 한공주                               122.90
# 해리가 샐리를 만났을 때                      26.67
# 핵소 고지                              36.80
# 행복 목욕탕                            217.41
# 헤드윅                               385.13
# 환상의 빛                              32.08
# 흑집사 : 북 오브 더 아틀란틱                 213.08
# 히든 피겨스                            411.79
#
# [204 rows x 1 columns]

# %% [markdown]
# - 결과에 대한 정렬을 필요할 경우 sort_values(by= , ascending=)

# %%
movie_pivot_sort = movie_pivot.sort_values(by='point', ascending=False)

# %%
movie_pivot_sort.head()
# Out:
#                 point
# name
# 댄서             914.60
# 서서평, 천천히 평온하게  889.64
# 오두막            861.65
# 라라랜드           858.89
# 너의 이름은.        738.42

# %%
temp = movieDF.query('name == ["히든 피겨스"]')

# %% [markdown]
# temp

# %% [markdown]
# - 시각화

# %%
plt.figure(figsize=(12,8))
plt.plot(temp['date'], temp['point'])
plt.legend(loc='best')
plt.grid()
plt.show()

# %% [markdown]
# - 영화별 날짜 변화에 따른 평점 변화 시각화 (실습)

# %%
movie_date_point_pivot = pd.pivot_table(movieDF , index=['date'] , columns=['name'], values=['point'])

# %%
movie_date_point_pivot
# Out:
#            point                                                         \
# name         10분 47 미터 500일의 썸머 7년-그들이 없는 언론 7번째 내가 죽던 날 7인의 사무라이  8 마일
# date
# 2017-05-01  8.89   NaN      NaN          NaN         NaN      NaN   NaN
# 2017-05-02  8.89   NaN      NaN          NaN         NaN      NaN   NaN
# 2017-05-03  8.89   NaN      NaN          NaN         NaN      NaN   NaN
# 2017-05-04  8.89   NaN      NaN          NaN         NaN      NaN   NaN
# 2017-05-05  8.89   NaN      NaN          NaN         NaN      NaN   NaN
# 2017-05-06  8.89   NaN      NaN          NaN         NaN      NaN   NaN
# 2017-05-07  8.89   NaN      NaN          NaN         NaN      NaN   NaN
# 2017-05-08  8.89   NaN      NaN          NaN         NaN      NaN   NaN
# 2017-05-09  8.89   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-10  8.89   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-11  8.89   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-12  8.89   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-13  8.89   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-14  8.89   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-15   NaN   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-16   NaN   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-17   NaN   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-18   NaN   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-19   NaN   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-20   NaN   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-21   NaN   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-22   NaN   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-23   NaN   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-24   NaN   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-25   NaN   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-26   NaN   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-27   NaN   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-28   NaN   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-29   NaN   NaN      NaN          NaN         NaN      NaN  8.88
# 2017-05-30   NaN   NaN      NaN          NaN         NaN      NaN  8.88
# ...          ...   ...      ...          ...         ...      ...   ...
# 2017-07-10   NaN   NaN      NaN         8.58        7.84      NaN   NaN
# 2017-07-11   NaN   NaN      NaN         8.58        7.84      NaN   NaN
# 2017-07-12   NaN   NaN      NaN         8.58        7.84      NaN   NaN
# 2017-07-13   NaN   NaN      NaN         8.58        7.84      NaN   NaN
# 2017-07-14   NaN   NaN      NaN         8.58        7.83      NaN   NaN
# 2017-07-15   NaN   NaN      NaN         8.58        7.84      NaN   NaN
# 2017-07-16   NaN   NaN      NaN         8.58        7.85      NaN   NaN
# 2017-07-17   NaN   NaN      NaN         8.58        7.83      NaN   NaN
# 2017-07-18   NaN   NaN      NaN         8.58        7.83      NaN   NaN
# 2017-07-19   NaN   NaN      NaN         8.58        7.83      NaN   NaN
# 2017-07-20   NaN  7.48      NaN          NaN        7.84      NaN   NaN
# 2017-07-21   NaN  7.34      NaN          NaN        7.84      NaN   NaN
# 2017-07-22   NaN  7.79      NaN          NaN        7.84      NaN   NaN
# 2017-07-23   NaN  7.58      NaN          NaN        7.84      NaN   NaN
# 2017-07-24   NaN  7.55      NaN          NaN        7.84     9.15   NaN
# 2017-07-25   NaN  7.53      NaN          NaN        7.84     9.15   NaN
# 2017-07-26   NaN  7.48      NaN          NaN        7.84     9.15   NaN
# 2017-07-27   NaN  7.49      NaN          NaN        7.85     9.15   NaN
# 2017-07-28   NaN  7.46      NaN          NaN        7.85      NaN   NaN
# 2017-07-29   NaN  7.45      NaN          NaN        7.85      NaN   NaN
# 2017-07-30   NaN  7.46      NaN          NaN        7.84      NaN   NaN
# 2017-07-31   NaN  7.43     8.39          NaN        7.84      NaN   NaN
# 2017-08-01   NaN  7.42     8.39          NaN        7.84      NaN   NaN
# 2017-08-02   NaN  7.41     8.39          NaN        7.85      NaN   NaN
# 2017-08-03   NaN  7.40     8.39          NaN        7.84      NaN   NaN
# 2017-08-04   NaN  7.40     8.39          NaN        7.84      NaN   NaN
# 2017-08-05   NaN  7.40     8.39          NaN        7.84      NaN   NaN
# 2017-08-06   NaN  7.39     8.39          NaN        7.84      NaN   NaN
# 2017-08-07   NaN  7.39     8.39          NaN        7.84      NaN   NaN
# 2017-08-08   NaN  7.38     8.39          NaN        7.85      NaN   NaN
#
#                                                  ...                           \
# name       가디언즈 오브 갤럭시 가디언즈 오브 갤럭시 VOL. 2  겟 아웃  ...   하울의 움직이는 성 하이큐!! 끝과 시작
# date                                             ...
# 2017-05-01        8.56                NaN   NaN  ...          NaN         NaN
# 2017-05-02        8.56                NaN   NaN  ...          NaN         NaN
# 2017-05-03         NaN               9.22   NaN  ...          NaN         NaN
# 2017-05-04         NaN               9.15   NaN  ...          NaN         NaN
# 2017-05-05         NaN               9.08   NaN  ...          NaN         NaN
# 2017-05-06         NaN               9.05   NaN  ...          NaN         NaN
# 2017-05-07        8.55               9.02   NaN  ...          NaN         NaN
# 2017-05-08         NaN               9.00   NaN  ...          NaN         NaN
# 2017-05-09         NaN               8.99   NaN  ...          NaN         NaN
# 2017-05-10         NaN               8.98   NaN  ...          NaN         NaN
# 2017-05-11         NaN               8.98   NaN  ...          NaN         NaN
# 2017-05-12         NaN               8.97   NaN  ...          NaN         NaN
# 2017-05-13         NaN               8.96   NaN  ...          NaN         NaN
# 2017-05-14        8.55               8.97   NaN  ...          NaN         NaN
# 2017-05-15         NaN               8.96   NaN  ...          NaN         NaN
# 2017-05-16         NaN               8.96   NaN  ...          NaN         NaN
# 2017-05-17         NaN               8.96  8.36  ...          NaN         NaN
# 2017-05-18         NaN               8.96  8.18  ...          NaN         NaN
# 2017-05-19         NaN               8.96  8.20  ...          NaN         NaN
# 2017-05-20         NaN               8.96  8.18  ...          NaN         NaN
# 2017-05-21         NaN               8.96  8.18  ...          NaN         NaN
# 2017-05-22         NaN               8.96  8.11  ...          NaN         NaN
# 2017-05-23         NaN               8.96  8.15  ...          NaN         NaN
# 2017-05-24         NaN               8.96  8.15  ...          NaN         NaN
# 2017-05-25         NaN               8.96  8.15  ...          NaN         NaN
# 2017-05-26         NaN               8.96  8.16  ...          NaN         NaN
# 2017-05-27         NaN               8.96  8.16  ...          NaN         NaN
# 2017-05-28         NaN               8.96  8.16  ...          NaN         NaN
# 2017-05-29         NaN               8.96  8.15  ...          NaN         NaN
# 2017-05-30         NaN               8.96  8.14  ...          NaN         NaN
# ...                ...                ...   ...  ...          ...         ...
# 2017-07-10         NaN                NaN  8.20  ...          9.1         NaN
# 2017-07-11         NaN                NaN  8.21  ...          9.1         NaN
# 2017-07-12         NaN                NaN  8.21  ...          9.1         NaN
# 2017-07-13         NaN                NaN  8.21  ...          9.1         NaN
# 2017-07-14         NaN                NaN  8.21  ...          9.1         NaN
# 2017-07-15         NaN                NaN  8.21  ...          9.1         NaN
# 2017-07-16         NaN                NaN  8.21  ...          9.1         NaN
# 2017-07-17         NaN                NaN  8.21  ...          NaN         NaN
# 2017-07-18         NaN                NaN  8.21  ...          NaN         NaN
# 2017-07-19         NaN                NaN  8.21  ...          NaN         NaN
# 2017-07-20         NaN                NaN  8.21  ...          NaN         NaN
# 2017-07-21         NaN                NaN  8.21  ...          NaN         NaN
# 2017-07-22         NaN                NaN  8.21  ...          NaN         NaN
# 2017-07-23         NaN                NaN  8.21  ...          NaN         NaN
# 2017-07-24         NaN                NaN  8.21  ...          NaN         NaN
# 2017-07-25         NaN                NaN  8.21  ...          NaN         NaN
# 2017-07-26         NaN                NaN  8.21  ...          NaN         NaN
# 2017-07-27         NaN                NaN  8.21  ...          NaN         NaN
# 2017-07-28         NaN                NaN  8.21  ...          NaN         NaN
# 2017-07-29         NaN                NaN  8.21  ...          NaN         NaN
# 2017-07-30         NaN                NaN  8.21  ...          NaN         NaN
# 2017-07-31         NaN                NaN  8.21  ...          NaN         NaN
# 2017-08-01         NaN                NaN  8.21  ...          NaN         NaN
# 2017-08-02         NaN                NaN   NaN  ...          NaN         NaN
# 2017-08-03         NaN                NaN   NaN  ...          NaN         NaN
# 2017-08-04         NaN                NaN   NaN  ...          NaN         NaN
# 2017-08-05         NaN                NaN   NaN  ...          NaN         NaN
# 2017-08-06         NaN                NaN   NaN  ...          NaN         NaN
# 2017-08-07         NaN                NaN   NaN  ...          NaN         NaN
# 2017-08-08         NaN                NaN   NaN  ...          NaN         NaN
#
#                                                                            \
# name         한공주 해리가 샐리를 만났을 때 핵소 고지 행복 목욕탕   헤드윅 환상의 빛 흑집사 : 북 오브 더 아틀란틱
# date
# 2017-05-01  8.78          8.89   NaN   8.70   NaN   NaN              9.20
# 2017-05-02  8.78          8.89   NaN   8.68   NaN   NaN              9.21
# 2017-05-03  8.78          8.89   NaN   8.70   NaN   NaN              9.22
# 2017-05-04  8.78           NaN   NaN   8.67   NaN   NaN              9.23
# 2017-05-05  8.78           NaN   NaN   8.69   NaN   NaN              9.24
# 2017-05-06  8.78           NaN   NaN   8.68   NaN   NaN              9.25
# 2017-05-07  8.78           NaN   NaN   8.68   NaN   NaN              9.27
# 2017-05-08  8.78           NaN   NaN   8.69   NaN   NaN              9.28
# 2017-05-09  8.78           NaN   NaN   8.69   NaN   NaN              9.28
# 2017-05-10  8.78           NaN   NaN   8.71   NaN   NaN              9.28
# 2017-05-11  8.78           NaN   NaN   8.71   NaN   NaN              9.28
# 2017-05-12  8.78           NaN   NaN   8.71   NaN   NaN              9.27
# 2017-05-13  8.77           NaN   NaN   8.70   NaN   NaN              9.28
# 2017-05-14  8.77           NaN   NaN   8.71   NaN   NaN              9.29
# 2017-05-15   NaN           NaN   NaN   8.69   NaN   NaN              9.29
# 2017-05-16   NaN           NaN   NaN   8.70   NaN   NaN              9.29
# 2017-05-17   NaN           NaN   NaN   8.70   NaN   NaN              9.27
# 2017-05-18   NaN           NaN   NaN   8.70   NaN   NaN              9.28
# 2017-05-19   NaN           NaN   NaN   8.70   NaN   NaN              9.28
# 2017-05-20   NaN           NaN   NaN   8.71   NaN   NaN              9.28
# 2017-05-21   NaN           NaN   NaN    NaN   NaN   NaN              9.28
# 2017-05-22   NaN           NaN   NaN    NaN   NaN   NaN              9.26
# 2017-05-23   NaN           NaN   NaN    NaN   NaN   NaN              9.27
# 2017-05-24   NaN           NaN   NaN    NaN   NaN   NaN               NaN
# 2017-05-25   NaN           NaN   NaN    NaN   NaN   NaN               NaN
# 2017-05-26   NaN           NaN   NaN    NaN   NaN   NaN               NaN
# 2017-05-27   NaN           NaN   NaN    NaN   NaN   NaN               NaN
# 2017-05-28   NaN           NaN   NaN    NaN   NaN   NaN               NaN
# 2017-05-29   NaN           NaN   NaN    NaN   NaN   NaN               NaN
# 2017-05-30   NaN           NaN   9.2   8.70   NaN   NaN               NaN
# ...          ...           ...   ...    ...   ...   ...               ...
# 2017-07-10   NaN           NaN   NaN    NaN  9.17   NaN               NaN
# 2017-07-11   NaN           NaN   NaN    NaN  9.17   NaN               NaN
# 2017-07-12   NaN           NaN   NaN    NaN  9.18   NaN               NaN
# 2017-07-13   NaN           NaN   NaN    NaN  9.18   NaN               NaN
# 2017-07-14   NaN           NaN   NaN    NaN  9.18   NaN               NaN
# 2017-07-15   NaN           NaN   NaN    NaN  9.17   NaN               NaN
# 2017-07-16   NaN           NaN   NaN    NaN  9.17   NaN               NaN
# 2017-07-17   NaN           NaN   NaN    NaN  9.17  8.02               NaN
# 2017-07-18   NaN           NaN   NaN    NaN  9.17  8.02               NaN
# 2017-07-19   NaN           NaN   NaN    NaN  9.17  8.02               NaN
# 2017-07-20   NaN           NaN   NaN    NaN  9.17  8.02               NaN
# 2017-07-21   NaN           NaN   NaN    NaN  9.17   NaN               NaN
# 2017-07-22   NaN           NaN   NaN    NaN  9.17   NaN               NaN
# 2017-07-23   NaN           NaN   NaN    NaN  9.17   NaN               NaN
# 2017-07-24   NaN           NaN   NaN    NaN  9.17   NaN               NaN
# 2017-07-25   NaN           NaN   NaN    NaN  9.17   NaN               NaN
# 2017-07-26   NaN           NaN   NaN    NaN  9.17   NaN               NaN
# 2017-07-27   NaN           NaN   NaN    NaN  9.17   NaN               NaN
# 2017-07-28   NaN           NaN   NaN    NaN  9.17   NaN               NaN
# 2017-07-29   NaN           NaN   NaN    NaN  9.18   NaN               NaN
# 2017-07-30   NaN           NaN   NaN    NaN  9.18   NaN               NaN
# 2017-07-31   NaN           NaN   NaN    NaN  9.18   NaN               NaN
# 2017-08-01   NaN           NaN   NaN    NaN  9.18   NaN               NaN
# 2017-08-02   NaN           NaN   NaN    NaN  9.18   NaN               NaN
# 2017-08-03   NaN           NaN   NaN    NaN  9.18   NaN               NaN
# 2017-08-04   NaN           NaN   NaN    NaN  9.18   NaN               NaN
# 2017-08-05   NaN           NaN   NaN    NaN  9.18   NaN               NaN
# 2017-08-06   NaN           NaN   NaN    NaN  9.18   NaN               NaN
# 2017-08-07   NaN           NaN   NaN    NaN  9.18   NaN               NaN
# 2017-08-08   NaN           NaN   NaN    NaN  9.18   NaN               NaN
#
#
# name       히든 피겨스
# date
# 2017-05-01   9.38
# 2017-05-02   9.37
# 2017-05-03   9.38
# 2017-05-04   9.38
# 2017-05-05   9.37
# 2017-05-06   9.37
# 2017-05-07   9.37
# 2017-05-08   9.36
# 2017-05-09   9.36
# 2017-05-10   9.36
# 2017-05-11   9.36
# 2017-05-12   9.36
# 2017-05-13   9.36
# 2017-05-14   9.36
# 2017-05-15   9.36
# 2017-05-16   9.36
# 2017-05-17   9.36
# 2017-05-18   9.36
# 2017-05-19   9.36
# 2017-05-20   9.36
# 2017-05-21   9.36
# 2017-05-22   9.36
# 2017-05-23   9.36
# 2017-05-24   9.36
# 2017-05-25   9.36
# 2017-05-26   9.36
# 2017-05-27   9.36
# 2017-05-28   9.36
# 2017-05-29   9.36
# 2017-05-30   9.35
# ...           ...
# 2017-07-10    NaN
# 2017-07-11    NaN
# 2017-07-12    NaN
# 2017-07-13    NaN
# 2017-07-14    NaN
# 2017-07-15    NaN
# 2017-07-16    NaN
# 2017-07-17    NaN
# 2017-07-18    NaN
# 2017-07-19    NaN
# 2017-07-20    NaN
# 2017-07-21    NaN
# 2017-07-22    NaN
# 2017-07-23    NaN
# 2017-07-24    NaN
# 2017-07-25    NaN
# 2017-07-26    NaN
# 2017-07-27    NaN
# 2017-07-28    NaN
# 2017-07-29    NaN
# 2017-07-30    NaN
# 2017-07-31    NaN
# 2017-08-01    NaN
# 2017-08-02    NaN
# 2017-08-03    NaN
# 2017-08-04    NaN
# 2017-08-05    NaN
# 2017-08-06    NaN
# 2017-08-07    NaN
# 2017-08-08    NaN
#
# [100 rows x 204 columns]

# %%
# movie_date_point_pivot.columns = movie_date_point_pivot.columns.droplevel()

# %%
# movie_date_point_pivot.head()
# Out:
# name         10분  47 미터  500일의 썸머  7년-그들이 없는 언론  7번째 내가 죽던 날  7인의 사무라이  8 마일  \
# date
# 2017-05-01  8.89    NaN       NaN           NaN          NaN       NaN   NaN
# 2017-05-02  8.89    NaN       NaN           NaN          NaN       NaN   NaN
# 2017-05-03  8.89    NaN       NaN           NaN          NaN       NaN   NaN
# 2017-05-04  8.89    NaN       NaN           NaN          NaN       NaN   NaN
# 2017-05-05  8.89    NaN       NaN           NaN          NaN       NaN   NaN
#
# name        가디언즈 오브 갤럭시  가디언즈 오브 갤럭시 VOL. 2  겟 아웃   ...    하울의 움직이는 성  \
# date                                                ...
# 2017-05-01         8.56                 NaN   NaN   ...           NaN
# 2017-05-02         8.56                 NaN   NaN   ...           NaN
# 2017-05-03          NaN                9.22   NaN   ...           NaN
# 2017-05-04          NaN                9.15   NaN   ...           NaN
# 2017-05-05          NaN                9.08   NaN   ...           NaN
#
# name        하이큐!! 끝과 시작   한공주  해리가 샐리를 만났을 때  핵소 고지  행복 목욕탕  헤드윅  환상의 빛  \
# date
# 2017-05-01          NaN  8.78           8.89    NaN    8.70  NaN    NaN
# 2017-05-02          NaN  8.78           8.89    NaN    8.68  NaN    NaN
# 2017-05-03          NaN  8.78           8.89    NaN    8.70  NaN    NaN
# 2017-05-04          NaN  8.78            NaN    NaN    8.67  NaN    NaN
# 2017-05-05          NaN  8.78            NaN    NaN    8.69  NaN    NaN
#
# name        흑집사 : 북 오브 더 아틀란틱  히든 피겨스
# date
# 2017-05-01               9.20    9.38
# 2017-05-02               9.21    9.37
# 2017-05-03               9.22    9.38
# 2017-05-04               9.23    9.38
# 2017-05-05               9.24    9.37
#
# [5 rows x 204 columns]

# %%
# 한글 폰트 문제 해결
import platform

from matplotlib import font_manager, rc
# plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
target_col = ['행복 목욕탕', '한공주', '히든 피겨스', '비포 선라이즈', '500일의 썸머']
plt.figure(figsize=(12,8))
plt.plot(movie_date_point_pivot[target_col])
plt.legend(target_col, loc='best')
plt.grid()
plt.show()
